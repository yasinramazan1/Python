# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("filmler.xlsx")

# %%
data
# Out:
#                              FİLM SENARYO OYUNCU YARDIMCI O. KURGU GÖRSEL  \
# 0                 SUSPIRIA (2018)       K    NaN           K     A      K
# 1                     TAXI DRIVER       A      K         NaN     A      A
# 2                   THE GENTLEMEN     NaN    NaN         NaN     A    NaN
# 3                        PARASITE       K      A           A     K      K
# 4                      KNIVES OUT       A      A         NaN     A      A
# 5                         GET OUT       K      A         NaN     A    NaN
# 6                              US     NaN    NaN         NaN   NaN    NaN
# 7                      GREEN BOOK       A    NaN           A     A    NaN
# 8               CAPTAIN FANTASTIC     NaN      A         NaN   NaN    NaN
# 9                            1917     NaN      A         NaN     K      K
# 10                 FORD V FERRARI       A      K         NaN   NaN      A
# 11                SUSPIRIA (1977)     NaN    NaN         NaN     A      K
# ...

# %%
data.head(5)
# Out:
#               FİLM SENARYO OYUNCU YARDIMCI O. KURGU GÖRSEL KOSTÜM MAKYAJ  \
# 0  SUSPIRIA (2018)       K    NaN           K     A      K      A      K
# 1      TAXI DRIVER       A      K         NaN     A      A    NaN    NaN
# 2    THE GENTLEMEN     NaN    NaN         NaN     A    NaN      A    NaN
# 3         PARASITE       K      A           A     K      K      A      A
# 4       KNIVES OUT       A      A         NaN     A      A      K      A
#
#   MÜZİK YÖNETMEN EN İYİ FİLM  ADAYLIK  KAZANDI  PUAN
# 0     K        A           A        9        5   8.0
# 1   NaN        A           A        6        1   7.5
# 2   NaN      NaN         NaN        2        0   7.0
# 3     A        K           K       10        5   8.5
# 4   NaN      NaN           A        7        1   8.0

# %%
# Tekrar eden verileri görmek istemediğimizde 
data["PUAN"].unique()
# Out:
# array([8. , 7.5, 7. , 8.5, 6. , 6.5, 5. , 9. , 8.8])

# %%
# Hangi puan kaç defa verilmiş?
data["PUAN"].value_counts()
# Out:
# 7.5    18
# 7.0    17
# 8.0     5
# 8.5     4
# 6.5     4
# 6.0     3
# 5.0     1
# 9.0     1
# 8.8     1
# Name: PUAN, dtype: int64

# %%
def besliPuanSistemi(puan):
    return puan/2

# %%
data["PUAN"].head()
# Out:
# 0    8.0
# 1    7.5
# 2    7.0
# 3    8.5
# 4    8.0
# Name: PUAN, dtype: float64

# %%
data["PUAN"].apply(besliPuanSistemi)
# Out:
# 0     4.00
# 1     3.75
# 2     3.50
# 3     4.25
# 4     4.00
# 5     3.75
# 6     3.00
# 7     3.75
# 8     3.50
# 9     3.75
# 10    3.75
# 11    3.25
# 12    3.50
# 13    3.75
# 14    3.50
# 15    3.75
# 16    4.25
# 17    2.50
# 18    3.75
# 19    4.25
# 20    4.25
# 21    3.75
# 22    3.50
# 23    3.50
# 24    3.50
# 25    3.50
# 26    3.50
# 27    3.50
# 28    3.25
# 29    3.75
# 30    3.00
# 31    3.75
# 32    3.50
# 33    3.00
# 34    3.25
# 35    4.00
# 36    4.50
# 37    4.40
# 38    3.75
# 39    3.75
# 40    3.75
# 41    3.75
# 42    3.50
# 43    3.50
# 44    3.50
# 45    3.25
# 46    3.50
# 47    3.50
# 48    4.00
# 49    3.75
# 50    3.75
# 51    3.75
# 52    4.00
# 53    3.50
# Name: PUAN, dtype: float64
