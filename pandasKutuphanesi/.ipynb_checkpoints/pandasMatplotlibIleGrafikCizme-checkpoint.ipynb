# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
veri1 = range(15)

# %%
veri2 = np.linspace(1,20,15)
veri2
# Out:
# array([ 1.        ,  2.35714286,  3.71428571,  5.07142857,  6.42857143,
#         7.78571429,  9.14285714, 10.5       , 11.85714286, 13.21428571,
#        14.57142857, 15.92857143, 17.28571429, 18.64285714, 20.        ])

# %% [markdown]
# ## Grafik Oluşturma

# %%
plt.plot(veri1,veri2, "green")

# %%
veri2=veri2**2

# %%
plt.plot(veri1,veri2, "purple")

# %%
veri2=veri2**6

# %%
plt.plot(veri1,veri2, "yellow")
