# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
data = pd.read_excel("excelKayitYapilanVeriler.xlsx")

# %%
data
# Out:
#    Unnamed: 0  A   B
# 0           0  3   3
# 1           1  7   2
# 2           2  2   9
# 3           3  4   6
# 4           4  5   5
# 5           5  4  10
# 6           6  1   3
# 7           7  1   3
# 8           8  1  10
# 9           9  9   5

# %%
plt.plot(data)
# Out:
# [<matplotlib.lines.Line2D at 0x153c6fd8ca0>,
#  <matplotlib.lines.Line2D at 0x153c6fd8d00>,
#  <matplotlib.lines.Line2D at 0x153c6fd8e20>]

# %%
veri = (np.random.rand(10,2)*10).round()
veri
# Out:
# array([[ 0.,  8.],
#        [ 5.,  6.],
#        [ 8.,  0.],
#        [ 2.,  2.],
#        [ 6.,  4.],
#        [ 3.,  2.],
#        [ 3.,  8.],
#        [ 1.,  2.],
#        [ 0.,  4.],
#        [ 4., 10.]])

# %%
tablo = pd.DataFrame(data=veri, columns=["A","B"])
tablo
# Out:
#      A     B
# 0  0.0   8.0
# 1  5.0   6.0
# 2  8.0   0.0
# 3  2.0   2.0
# 4  6.0   4.0
# 5  3.0   2.0
# 6  3.0   8.0
# 7  1.0   2.0
# 8  0.0   4.0
# 9  4.0  10.0

# %%
plt.plot(tablo)
# Out:
# [<matplotlib.lines.Line2D at 0x153ce85dbb0>,
#  <matplotlib.lines.Line2D at 0x153ce85dc10>]

# %%
plt.plot(tablo,"green")
# Out:
# [<matplotlib.lines.Line2D at 0x153ce8bafa0>,
#  <matplotlib.lines.Line2D at 0x153ce8bafd0>]
