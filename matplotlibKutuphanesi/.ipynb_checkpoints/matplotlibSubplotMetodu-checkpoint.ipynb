# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
plt.subplot()
# Out:
# <AxesSubplot:>

# %%
plt.subplot(1,1,1)
# Out:
# <AxesSubplot:>

# %%
plt.subplot(2,1,1)
# Out:
# <AxesSubplot:>

# %%
plt.subplot(1,2,1)
# Out:
# <AxesSubplot:>

# %%
dizi1=range(10)
dizi2=range(5,15) # 5'ten 14 dahil 

plt.subplot(1,2,1)
plt.plot(dizi1, dizi2, "b*-")
plt.subplot(1,2,2)
plt.plot(dizi2, dizi1, "g--")
